# %% [markdown]
# ### Import libraries

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas.io.json import json_normalize

import time

from datetime import datetime
from dateutil import tz

from bibliopixel import *
from bibliopixel.drivers.LPD8806 import *
from bibliopixel import LEDStrip
import bibliopixel.colors as colors
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c336a55055fe> in <module>()
#      11 from dateutil import tz
#      12
# ---> 13 from bibliopixel import *
#      14 from bibliopixel.drivers.LPD8806 import *
#      15 from bibliopixel import LEDStrip
#
# ImportError: No module named 'bibliopixel'

# %%
## read data
df_total = pd.read_pickle('All_Meters_Concat')
df_new = pd.read_pickle('Dunne_Daily_Average')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      44         try:
# ---> 45             with open(path, 'rb') as fh:
#      46                 return pkl.load(fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dunne_All_Meters_Concat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      50             try:
# ---> 51                 with open(path, 'rb') as fh:
#      52                     return pc.load(fh, encoding=encoding, compat=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dunne_All_Meters_Concat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in read_pickle(path)
#      59     try:
# ---> 60         return try_read(path)
#      61     except:
#
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      55             except:
# ---> 56                 with open(path, 'rb') as fh:
#      57                     return pc.load(fh, encoding=encoding, compat=True)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dunne_All_Meters_Concat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      44         try:
# ---> 45             with open(path, 'rb') as fh:
#      46                 return pkl.load(fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dunne_All_Meters_Concat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      50             try:
# ---> 51                 with open(path, 'rb') as fh:
#      52                     return pc.load(fh, encoding=encoding, compat=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dunne_All_Meters_Concat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ff1e7788fbc8> in <module>()
#       1 ## read data
# ----> 2 df_total = pd.read_pickle('Dunne_All_Meters_Concat')
#       3 df_new = pd.read_pickle('Dunne_Daily_Average')
#
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in read_pickle(path)
#      61     except:
#      62         if PY3:
# ---> 63             return try_read(path, encoding='latin1')
#      64         raise
#
# /usr/local/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      54             # compat pickle
#      55             except:
# ---> 56                 with open(path, 'rb') as fh:
#      57                     return pc.load(fh, encoding=encoding, compat=True)
#      58
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dunne_All_Meters_Concat'

# %% [markdown]
# ### Generating color scale

# %%
red = 0
green = 255
stepSize = 50
color_gn_rd = []
color_gn_rd.append((red, green, 0)) ## the lights are GRB format

# %%
while(red < 255): ## start with green and increase red
    red += stepSize;
    if(red > 245):
        red = 255; 
    color_gn_rd.append((red, green, 0))

while(green > 0): ## start with red + green and decrease green
    green -= stepSize;
    if(green < 6):
        green = 0; 
    color_gn_rd.append((red, green, 0)); 
    
total_colors = len(color_gn_rd)

# %% [markdown]
# ### Setting up LEDs

# %%
LedsPerSide = 10
numLeds= LedsPerSide*4*2 ##x/side * 4 sides * 2 levels
driver=DriverLPD8806(numLeds, ChannelOrder.BRG)
led=LEDStrip(driver)
# Out:
# ERROR - spi_driver_base - Unable to import spidev. Please install. pip install spidev
# ERROR:BiblioPixel:Unable to import spidev. Please install. pip install spidev
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-a46884187669> in <module>()
#       1 LedsPerSide = 10
#       2 numLeds= LedsPerSide*4*2 ##x/side * 4 sides * 2 levels
# ----> 3 driver=DriverLPD8806(numLeds, ChannelOrder.BRG)
#       4 led=LEDStrip(driver)
#
# /usr/local/lib/python2.7/site-packages/bibliopixel/drivers/LPD8806.pyc in __init__(self, num, c_order, use_py_spi, dev, SPISpeed)
#       5
#       6     def __init__(self, num, c_order = ChannelOrder.RGB, use_py_spi = True, dev="/dev/spidev0.0", SPISpeed = 2):
# ----> 7         super(DriverLPD8806, self).__init__(num, c_order = c_order, use_py_spi = use_py_spi, dev = dev, SPISpeed = SPISpeed)
#       8
#       9         # Color calculations from
#
# /usr/local/lib/python2.7/site-packages/bibliopixel/drivers/spi_driver_base.pyc in __init__(self, num, c_order, use_py_spi, dev, SPISpeed)
#      39                 raise ValueError(error)
#      40
# ---> 41             self._bootstrapSPIDev()
#      42             import spidev
#      43             self.spi = spidev.SpiDev()
#
# /usr/local/lib/python2.7/site-packages/bibliopixel/drivers/spi_driver_base.pyc in _bootstrapSPIDev(self)
#      57                 error = "Unable to import spidev. Please install. pip install spidev"
#      58                 log.logger.error(error)
# ---> 59                 raise ImportError(error)
#      60
#      61         if not os.path.exists(self.dev):
#
# ImportError: Unable to import spidev. Please install. pip install spidev

# %% [markdown]
# ### Defining Flashing modes

# %%
def led_set(start_position, numLEDs, color): ## Fills the colors
    #led.fill(color, start=start_position,end=start_position+numLEDs)
    #led.update()
    print color
    return

def led_pulse(start_position, numLEDs, color):
    ## Step-up intensity by 10% increments, then step down by the same every 0.1 seconds. total time = 4 sec
    
    intensity = np.arange(0,1.1,0.1) 

    for i in intensity:
        color_new = (int(color[0]*i),int(color[1]*i),int(color[2]*i)) 
        # There is probably a more elegant way to do this.. 
        print color_new
        #led.fill(color_new, start=start_position,end=start_position+numLEDs)
        #led.update()
        time.sleep(0.1)

    for i in reversed(intensity):
        color_new = (int(color[0]*i),int(color[1]*i),int(color[2]*i)) 
        print color_new
        #led.fill(color_new, start=start_position,end=start_position+numLEDs)
        #led.update()
        time.sleep(0.1)

# %% [markdown]
# ### Calculate Average Data

# %%
df_total
# Out:
#       duration          time_stamp   value   meter ID
# 0         1800 2015-01-16 01:00:00   0.000  141501550
# 1         1800 2015-01-16 01:30:00   0.000  141501550
# 2         1800 2015-01-16 02:00:00   0.000  141501550
# 3         1800 2015-01-16 02:30:00   0.000  141501550
# 4         1800 2015-01-16 03:00:00   0.000  141501550
# 5         1800 2015-01-16 03:30:00   0.000  141501550
# 6         1800 2015-01-16 04:00:00   0.000  141501550
# 7         1800 2015-01-16 04:30:00   0.000  141501550
# 8         1800 2015-01-16 05:00:00   0.000  141501550
# 9         1800 2015-01-16 05:30:00   0.000  141501550
# 10        1800 2015-01-16 06:00:00   0.000  141501550
# 11        1800 2015-01-16 06:30:00   0.000  141501550
# 12        1800 2015-01-16 07:00:00   0.000  141501550
# 13        1800 2015-01-16 07:30:00   0.000  141501550
# 14        1800 2015-01-16 08:00:00   0.000  141501550
# 15        1800 2015-01-16 08:30:00   0.000  141501550
# 16        1800 2015-01-16 09:00:00   0.000  141501550
# 17        1800 2015-01-16 09:30:00   0.000  141501550
df_Dailygroup = df_total.groupby('Date')
df_DailyAverage = df_Dailygroup['value'].mean()*2
df_DailyTotal = df_Dailygroup['value'].sum()
df_DailyAverage.to_csv('Dunne_Daily_Average_KW.csv', sep=',')
df_DailyTotal.to_csv('Dunne_Daily_Total_KWH.csv', sep=',')

# %%
df_Monthly
# Out:
# Month
# 1     25.942860
# 2     32.340975
# 3     21.111393
# 4      9.046900
# 5      7.845363
# 6      7.065050
# 7      7.820734
# 8      1.971191
# 9      9.496408
# 10     8.695065
# 11    13.732055
# 12    11.490742
# Name: value, dtype: float64

# %%
df_group = df_total.groupby('time_stamp')
df_new = df_group['value'].sum()

df_1Week = df_new[(df_new.index > '2015-9-19 00:00:00') & (df_new.index < '2015-9-26 00:00:00')]
df_1Week
df_1Week.to_csv('df_1Week_Dunne.csv', sep=',')

# %%
df_DailyAverage = df_Dailygroup['value'].sum()
df_new.to_csv('df_dailytotal_dunne.csv', sep=',')

df_RollingMean = pd.rolling_mean(df_new, 30)
df_RollingMean
df_new
# Out:
# time_stamp
# 2015-01-16 01:00:00    54.252
# 2015-01-16 01:30:00    55.044
# 2015-01-16 02:00:00    55.908
# 2015-01-16 02:30:00    55.476
# 2015-01-16 03:00:00    55.764
# 2015-01-16 03:30:00    55.683
# 2015-01-16 04:00:00    56.259
# 2015-01-16 04:30:00    55.755
# 2015-01-16 05:00:00    55.611
# 2015-01-16 05:30:00    56.250
# 2015-01-16 06:00:00    57.186
# 2015-01-16 06:30:00    56.331
# 2015-01-16 07:00:00    57.987
# 2015-01-16 07:30:00    59.724
# 2015-01-16 08:00:00    62.784
# 2015-01-16 08:30:00    61.560
# 2015-01-16 09:00:00    62.703
# 2015-01-16 09:30:00    70.839
# 2015-01-16 10:00:00    67.671
# 2015-01-16 10:30:00    65.592
# 2015-01-16 11:00:00    62.712
# 2015-01-16 11:30:00    59.040
# 2015-01-16 12:00:00    52.056
# 2015-01-16 12:30:00    50.247
# 2015-01-16 13:00:00    49.752
# 2015-01-16 13:30:00    50.895
# 2015-01-16 14:00:00    53.559
# 2015-01-16 14:30:00    51.696
# 2015-01-16 15:00:00    51.255
# 2015-01-16 15:30:00    49.662
#                         ...
# 2016-02-16 04:00:00    32.525
# 2016-02-16 04:30:00    33.413
# 2016-02-16 05:00:00    33.651
# 2016-02-16 05:30:00    24.965
# 2016-02-16 06:00:00    28.925
# 2016-02-16 06:30:00    33.771
# 2016-02-16 07:00:00    21.893
# 2016-02-16 07:30:00    28.565
# 2016-02-16 08:00:00    23.931
# 2016-02-16 08:30:00    27.173
# 2016-02-16 09:00:00    28.805
# 2016-02-16 09:30:00    20.883
# 2016-02-16 10:00:00    30.893
# 2016-02-16 10:30:00    29.093
# 2016-02-16 11:00:00    28.445
# 2016-02-16 11:30:00    22.851
# 2016-02-16 12:00:00    28.685
# 2016-02-16 12:30:00    22.133
# 2016-02-16 13:00:00    37.971
# 2016-02-16 13:30:00    30.485
# 2016-02-16 14:00:00    34.493
# 2016-02-16 14:30:00    30.003
# 2016-02-16 15:00:00    28.805
# 2016-02-16 15:30:00    38.165
# 2016-02-16 16:00:00    33.363
# 2016-02-16 16:30:00    28.685
# 2016-02-16 17:00:00    38.813
# 2016-02-16 17:30:00    30.723
# 2016-02-16 18:00:00    35.933
# 2016-02-16 18:30:00    33.005
# Name: value, dtype: float64

# %% [markdown]
# ### Displaying Daily Total Values for the entire year of data

# %%
df_DailyAverage = pd.read_csv('df_DailyAverage_Dunne.csv',  parse_dates=True)
df_RollingMean = pd.read_csv('df_RollingMean_Dunne.csv',  parse_dates=True)
df_1Week = pd.read_csv('df_1Week_Dunne.csv', parse_dates=True)

# %%
def yearly_data():
    while (True):
        print 'Starting Display'
        print 'Press \'Control + C\' to stop'
        max_value = df_DailyAverage.max()
        ScalingSteps = (max_value + 0.1)/(total_colors)
        for item in df_DailyAverage.iteritems():
            print 'Date: ', item[0]
            print 'Average use: ', item [1]
            color_index = int(item[1]/ScalingSteps)
            print color_index
            # print color_index
            color = color_gn_rd[color_index]
            led_set(0, 80, color)

# %% [markdown]
# ### Displaying Daily Energy Usage on Bottom with last 30 days' average on Top

# %%
def daily_vs_past30days():
    while (True):
        print 'Starting Display'
        print 'Press \'Control + C\' to stop'
        max_value = df_DailyAverage.max()
        ScalingSteps = (max_value + 0.1)/total_colors
        count = 0
        for item in df_DailyAverage.iteritems():
            print 'Date: ', item[0]
            print 'Total use: ', item [1]
            color_index = int(item[1]/ScalingSteps)

            # print color_index
            color = color_gn_rd[color_index]
            led_set(0, 40, color)

            print 'Last 30 days average: ', df_RollingMean[count]
            try:
                color_index = int(df_RollingMean[count]/ScalingSteps)
                color = color_gn_rd[color_index]
                led_set(40, 80, color)

            except:
                color = (0,0,0)
                led_set(40, 80, color)

            count = count + 1

# %% [markdown]
# ### Displaying 1 Week's Energy Use (res: every half-hour )

# %%
def OneWeek_data():
    time_stamp = []
    value = []
    with open('df_1Week_Dunne.csv') as f:
        cf = csv.DictReader(f, fieldnames=['time_stamp', 'value'])
        for row in cf:
            time_stamp.append(row['time_stamp'])
            value.append(float(row['value']))

    days = ['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
    max_value = max(value)
    ScalingSteps = (max_value + 0.1)/total_colors
    date = []
    while (True):
        print 'Starting Display'
        print 'Press \'Control + C\' to stop'
        
        count = 0
        for ts, val in zip(time_stamp, value):
            
            
            if(date != time.strftime("%Y-%m-%d",  time.strptime(ts, "%Y-%m-%d %H:%M:%S"))):
                print days[count]
                led_pulse(0, 80, (0,0,255))
                count = count + 1

            print 'Time: ', ts
            print 'Electricity Usage: ', val
            color_index = int((val)/ScalingSteps)

            print color_index
            color = color_gn_rd[color_index]
            led_set(0, 80, color)

            date = time.strftime("%Y-%m-%d",  time.strptime(ts, "%Y-%m-%d %H:%M:%S"))

# %%
print 'Functions Available:'
print 'yearly_data()'
print 'daily_vs_past30days()'
print 'OneWeek_data()'
# Out:
# Functions Available:
# yearly_data()
# daily_vs_past30days()
# OneWeek_data()

# %%
OneWeek_data()
# Out:
# Starting Display
# Press 'Control + C' to stop
# Saturday
# (0, 0, 0)
# (0, 0, 25)
# (0, 0, 51)
# (0, 0, 76)
# (0, 0, 102)
# (0, 0, 127)
# (0, 0, 153)
# (0, 0, 178)
# (0, 0, 204)
# (0, 0, 229)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 229)
# (0, 0, 204)
# (0, 0, 178)
# (0, 0, 153)
# (0, 0, 127)
# (0, 0, 102)
# (0, 0, 76)
# (0, 0, 51)
# (0, 0, 25)
# (0, 0, 0)
# Time:  2015-09-19 00:30:00
# Electricity Usage:  16.92
# 5
# (255, 255, 0)
# Time:  2015-09-19 01:00:00
# Electricity Usage:  17.208
# 5
# (255, 255, 0)
# Time:  2015-09-19 01:30:00
# Electricity Usage:  16.128
# 5
# (255, 255, 0)
# Time:  2015-09-19 02:00:00
# Electricity Usage:  16.2
# 5
# (255, 255, 0)
# Time:  2015-09-19 02:30:00
# Electricity Usage:  15.48
# 5
# (255, 255, 0)
# Time:  2015-09-19 03:00:00
# Electricity Usage:  16.272
# 5
# (255, 255, 0)
# Time:  2015-09-19 03:30:00
# Electricity Usage:  14.76
# 4
# (200, 255, 0)
# Time:  2015-09-19 04:00:00
# Electricity Usage:  14.904
# 4
# (200, 255, 0)
# Time:  2015-09-19 04:30:00
# Electricity Usage:  14.04
# 4
# (200, 255, 0)
# Time:  2015-09-19 05:00:00
# Electricity Usage:  14.832
# 4
# (200, 255, 0)
# Time:  2015-09-19 05:30:00
# Electricity Usage:  13.896
# 4
# (200, 255, 0)
# Time:  2015-09-19 06:00:00
# Electricity Usage:  11.88
# 3
# (150, 255, 0)
# Time:  2015-09-19 06:30:00
# Electricity Usage:  13.176
# 4
# (200, 255, 0)
# Time:  2015-09-19 07:00:00
# Electricity Usage:  12.456
# 4
# (200, 255, 0)
# Time:  2015-09-19 07:30:00
# Electricity Usage:  12.456
# 4
# (200, 255, 0)
# Time:  2015-09-19 08:00:00
# Electricity Usage:  12.6
# 4
# (200, 255, 0)
# Time:  2015-09-19 08:30:00
# Electricity Usage:  12.456
# 4
# (200, 255, 0)
# Time:  2015-09-19 09:00:00
# Electricity Usage:  13.32
# 4
# (200, 255, 0)
# Time:  2015-09-19 09:30:00
# Electricity Usage:  13.248
# 4
# (200, 255, 0)
# Time:  2015-09-19 10:00:00
# Electricity Usage:  14.112
# 4
# (200, 255, 0)
# Time:  2015-09-19 10:30:00
# Electricity Usage:  13.32
# 4
# (200, 255, 0)
# Time:  2015-09-19 11:00:00
# Electricity Usage:  14.544
# 4
# (200, 255, 0)
# Time:  2015-09-19 11:30:00
# Electricity Usage:  14.688
# 4
# (200, 255, 0)
# Time:  2015-09-19 12:00:00
# Electricity Usage:  14.688
# 4
# (200, 255, 0)
# Time:  2015-09-19 12:30:00
# Electricity Usage:  14.832
# 4
# (200, 255, 0)
# Time:  2015-09-19 13:00:00
# Electricity Usage:  15.192
# 4
# (200, 255, 0)
# Time:  2015-09-19 13:30:00
# Electricity Usage:  15.48
# 5
# (255, 255, 0)
# Time:  2015-09-19 14:00:00
# Electricity Usage:  14.688
# 4
# (200, 255, 0)
# Time:  2015-09-19 14:30:00
# Electricity Usage:  15.48
# 5
# (255, 255, 0)
# Time:  2015-09-19 15:00:00
# Electricity Usage:  14.544
# 4
# (200, 255, 0)
# Time:  2015-09-19 15:30:00
# Electricity Usage:  15.624
# 5
# (255, 255, 0)
# Time:  2015-09-19 16:00:00
# Electricity Usage:  15.048
# 4
# (200, 255, 0)
# Time:  2015-09-19 16:30:00
# Electricity Usage:  15.624
# 5
# (255, 255, 0)
# Time:  2015-09-19 17:00:00
# Electricity Usage:  14.544
# 4
# (200, 255, 0)
# Time:  2015-09-19 17:30:00
# Electricity Usage:  14.832
# 4
# (200, 255, 0)
# Time:  2015-09-19 18:00:00
# Electricity Usage:  14.616
# 4
# (200, 255, 0)
# Time:  2015-09-19 18:30:00
# Electricity Usage:  14.616
# 4
# (200, 255, 0)
# Time:  2015-09-19 19:00:00
# Electricity Usage:  13.104
# 4
# (200, 255, 0)
# Time:  2015-09-19 19:30:00
# Electricity Usage:  12.6
# 4
# (200, 255, 0)
# Time:  2015-09-19 20:00:00
# Electricity Usage:  12.384
# 4
# (200, 255, 0)
# Time:  2015-09-19 20:30:00
# Electricity Usage:  12.456
# 4
# (200, 255, 0)
# Time:  2015-09-19 21:00:00
# Electricity Usage:  12.456
# 4
# (200, 255, 0)
# Time:  2015-09-19 21:30:00
# Electricity Usage:  12.528
# 4
# (200, 255, 0)
# Time:  2015-09-19 22:00:00
# Electricity Usage:  11.736
# 3
# (150, 255, 0)
# Time:  2015-09-19 22:30:00
# Electricity Usage:  11.736
# 3
# (150, 255, 0)
# Time:  2015-09-19 23:00:00
# Electricity Usage:  11.664
# 3
# (150, 255, 0)
# Time:  2015-09-19 23:30:00
# Electricity Usage:  10.296
# 3
# (150, 255, 0)
# Sunday
# (0, 0, 0)
# (0, 0, 25)
# (0, 0, 51)
# (0, 0, 76)
# (0, 0, 102)
# (0, 0, 127)
# (0, 0, 153)
# (0, 0, 178)
# (0, 0, 204)
# (0, 0, 229)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 229)
# (0, 0, 204)
# (0, 0, 178)
# (0, 0, 153)
# (0, 0, 127)
# (0, 0, 102)
# (0, 0, 76)
# (0, 0, 51)
# (0, 0, 25)
# (0, 0, 0)
# Time:  2015-09-20 00:00:00
# Electricity Usage:  10.152
# 3
# (150, 255, 0)
# Time:  2015-09-20 00:30:00
# Electricity Usage:  11.016
# 3
# (150, 255, 0)
# Time:  2015-09-20 01:00:00
# Electricity Usage:  10.224
# 3
# (150, 255, 0)
# Time:  2015-09-20 01:30:00
# Electricity Usage:  10.296
# 3
# (150, 255, 0)
# Time:  2015-09-20 02:00:00
# Electricity Usage:  10.872
# 3
# (150, 255, 0)
# Time:  2015-09-20 02:30:00
# Electricity Usage:  10.296
# 3
# (150, 255, 0)
# Time:  2015-09-20 03:00:00
# Electricity Usage:  11.016
# 3
# (150, 255, 0)
# Time:  2015-09-20 03:30:00
# Electricity Usage:  10.296
# 3
# (150, 255, 0)
# Time:  2015-09-20 04:00:00
# Electricity Usage:  10.944
# 3
# (150, 255, 0)
# Time:  2015-09-20 04:30:00
# Electricity Usage:  11.016
# 3
# (150, 255, 0)
# Time:  2015-09-20 05:00:00
# Electricity Usage:  11.016
# 3
# (150, 255, 0)
# Time:  2015-09-20 05:30:00
# Electricity Usage:  10.08
# 3
# (150, 255, 0)
# Time:  2015-09-20 06:00:00
# Electricity Usage:  10.944
# 3
# (150, 255, 0)
# Time:  2015-09-20 06:30:00
# Electricity Usage:  10.944
# 3
# (150, 255, 0)
# Time:  2015-09-20 07:00:00
# Electricity Usage:  10.224
# 3
# (150, 255, 0)
# Time:  2015-09-20 07:30:00
# Electricity Usage:  10.872
# 3
# (150, 255, 0)
# Time:  2015-09-20 08:00:00
# Electricity Usage:  11.016
# 3
# (150, 255, 0)
# Time:  2015-09-20 08:30:00
# Electricity Usage:  12.384
# 4
# (200, 255, 0)
# Time:  2015-09-20 09:00:00
# Electricity Usage:  12.528
# 4
# (200, 255, 0)
# Time:  2015-09-20 09:30:00
# Electricity Usage:  13.824
# 4
# (200, 255, 0)
# Time:  2015-09-20 10:00:00
# Electricity Usage:  14.112
# 4
# (200, 255, 0)
# Time:  2015-09-20 10:30:00
# Electricity Usage:  13.752
# 4
# (200, 255, 0)
# Time:  2015-09-20 11:00:00
# Electricity Usage:  15.408
# 5
# (255, 255, 0)
# Time:  2015-09-20 11:30:00
# Electricity Usage:  13.896
# 4
# (200, 255, 0)
# Time:  2015-09-20 12:00:00
# Electricity Usage:  15.48
# 5
# (255, 255, 0)
# Time:  2015-09-20 12:30:00
# Electricity Usage:  15.12
# 4
# (200, 255, 0)
# Time:  2015-09-20 13:00:00
# Electricity Usage:  15.408
# 5
# (255, 255, 0)
# Time:  2015-09-20 13:30:00
# Electricity Usage:  14.472
# 4
# (200, 255, 0)
# Time:  2015-09-20 14:00:00
# Electricity Usage:  16.272
# 5
# (255, 255, 0)
# Time:  2015-09-20 14:30:00
# Electricity Usage:  15.12
# 4
# (200, 255, 0)
# Time:  2015-09-20 15:00:00
# Electricity Usage:  15.552
# 5
# (255, 255, 0)
# Time:  2015-09-20 15:30:00
# Electricity Usage:  15.408
# 5
# (255, 255, 0)
# Time:  2015-09-20 16:00:00
# Electricity Usage:  15.84
# 5
# (255, 255, 0)
# Time:  2015-09-20 16:30:00
# Electricity Usage:  15.48
# 5
# (255, 255, 0)
# Time:  2015-09-20 17:00:00
# Electricity Usage:  14.76
# 4
# (200, 255, 0)
# Time:  2015-09-20 17:30:00
# Electricity Usage:  15.408
# 5
# (255, 255, 0)
# Time:  2015-09-20 18:00:00
# Electricity Usage:  14.616
# 4
# (200, 255, 0)
# Time:  2015-09-20 18:30:00
# Electricity Usage:  13.896
# 4
# (200, 255, 0)
# Time:  2015-09-20 19:00:00
# Electricity Usage:  13.176
# 4
# (200, 255, 0)
# Time:  2015-09-20 19:30:00
# Electricity Usage:  13.176
# 4
# (200, 255, 0)
# Time:  2015-09-20 20:00:00
# Electricity Usage:  12.456
# 4
# (200, 255, 0)
# Time:  2015-09-20 20:30:00
# Electricity Usage:  12.312
# 4
# (200, 255, 0)
# Time:  2015-09-20 21:00:00
# Electricity Usage:  12.6
# 4
# (200, 255, 0)
# Time:  2015-09-20 21:30:00
# Electricity Usage:  13.104
# 4
# (200, 255, 0)
# Time:  2015-09-20 22:00:00
# Electricity Usage:  11.808
# 3
# (150, 255, 0)
# Time:  2015-09-20 22:30:00
# Electricity Usage:  12.384
# 4
# (200, 255, 0)
# Time:  2015-09-20 23:00:00
# Electricity Usage:  12.384
# 4
# (200, 255, 0)
# Time:  2015-09-20 23:30:00
# Electricity Usage:  12.312
# 4
# (200, 255, 0)
# Monday
# (0, 0, 0)
# (0, 0, 25)
# (0, 0, 51)
# (0, 0, 76)
# (0, 0, 102)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-34da9d58c3af> in <module>()
# ----> 1 OneWeek_data()
#
# <ipython-input-66-f2cb2e7a01e5> in OneWeek_data()
#      14             if(date != time.strftime("%Y-%m-%d",  time.strptime(ts, "%Y-%m-%d %H:%M:%S"))):
#      15                 print days[count]
# ---> 16                 led_pulse(0, 80, (0,0,255))
#      17                 count = count + 1
#      18
#
# <ipython-input-6-390350cc666a> in led_pulse(start_position, numLEDs, color)
#      16         #led.fill(color_new, start=start_position,end=start_position+numLEDs)
#      17         #led.update()
# ---> 18         time.sleep(0.1)
#      19
#      20     for i in reversed(intensity):
#
# KeyboardInterrupt:

# %%
time_stamp = []
value = []
with open('df_1Week_Dunne.csv') as f:
    cf = csv.DictReader(f, fieldnames=['time_stamp', 'value'])
    for row in cf:
        time_stamp.append(row['time_stamp'])
        value.append(float(row['value']))

# %%
time.strftime("%Y-%m-%d",  time.strptime(time_stamp[0], "%Y-%m-%d %H:%M:%S"))
# Out:
# '2015-09-19'

# %%
for items in df_1Week:
    print items['time_stamp']
# Out:
# 2015-09-19 00:30:00
# 2015-09-19 01:00:00
# 2015-09-19 01:30:00
# 2015-09-19 02:00:00
# 2015-09-19 02:30:00
# 2015-09-19 03:00:00
# 2015-09-19 03:30:00
# 2015-09-19 04:00:00
# 2015-09-19 04:30:00
# 2015-09-19 05:00:00
# 2015-09-19 05:30:00
# 2015-09-19 06:00:00
# 2015-09-19 06:30:00
# 2015-09-19 07:00:00
# 2015-09-19 07:30:00
# 2015-09-19 08:00:00
# 2015-09-19 08:30:00
# 2015-09-19 09:00:00
# 2015-09-19 09:30:00
# 2015-09-19 10:00:00
# 2015-09-19 10:30:00
# 2015-09-19 11:00:00
# 2015-09-19 11:30:00
# 2015-09-19 12:00:00
# 2015-09-19 12:30:00
# 2015-09-19 13:00:00
# 2015-09-19 13:30:00
# 2015-09-19 14:00:00
# 2015-09-19 14:30:00
# 2015-09-19 15:00:00
# 2015-09-19 15:30:00
# 2015-09-19 16:00:00
